# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
path = "Measurement_summary.csv"
seoul_air_df = pd.read_csv(path)
seoul_air_df.head()
# Out:
#    Measurement date  Station code  \
# 0  2017-01-01 00:00           101
# 1  2017-01-01 01:00           101
# 2  2017-01-01 02:00           101
# 3  2017-01-01 03:00           101
# 4  2017-01-01 04:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005007
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005007
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005007
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005007
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005007
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
# Create a filtered dataframe from specific columns
seoul_cols = ["Measurement date", "Station code", "SO2", "NO2", "O3", "CO", "PM10", "PM2.5"]
seoul_transformed= seoul_air_df[seoul_cols].copy()

# Rename the column headers
seoul_transformed = seoul_transformed.rename(columns={"Measurement date": "measurement_date",
                                                          "station code": "station_code",
                                                          "SO2": "sulfer_dioxide",
                                                           "NO2":"nitrous_dioxide",
                                                        "O3": "ozone",
                                                        "CO": "carbon_monoxide",
                                                        "PM10":"particulate_matter_10000nm",
                                                        "PM2.5":"particulate_matter_2500nm"})

seoul_transformed.head()
# Out:
#    measurement_date  Station code  sulfer_dioxide  nitrous_dioxide  ozone  \
# 0  2017-01-01 00:00           101           0.004            0.059  0.002
# 1  2017-01-01 01:00           101           0.004            0.058  0.002
# 2  2017-01-01 02:00           101           0.004            0.056  0.002
# 3  2017-01-01 03:00           101           0.004            0.056  0.002
# 4  2017-01-01 04:00           101           0.003            0.051  0.002
#
#    carbon_monoxide  particulate_matter_10000nm  particulate_matter_2500nm
# 0              1.2                        73.0                       57.0
# 1              1.2                        71.0                       59.0
# 2              1.2                        70.0                       59.0
# 3              1.2                        70.0                       58.0
# 4              1.2                        69.0                       61.0

# %%
address=seoul_air_df.iloc[0,2]
address
# Out:
# '19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republic of Korea'

# %%
path_2 = "air-quality-monitoring-2014-1.csv"
uk_air_df = pd.read_csv(path_2)
uk_air_df.head()
# Out:
#                                      OrganisationURI OrganisationLabel  \
# 0  http://opendatacommunities.org/id/london-borou...            Barnet
# 1  http://opendatacommunities.org/id/london-borou...            Barnet
# 2  http://opendatacommunities.org/id/london-borou...            Barnet
# 3  http://opendatacommunities.org/id/london-borou...            Barnet
# 4  http://opendatacommunities.org/id/london-borou...            Barnet
#
#   Air Quality Monitoring Station        Location                 Type  \
# 0                 Tally Ho AQMS   North Finchley  BN1: Urban Kerbside
# 1                 Tally Ho AQMS   North Finchley  BN1: Urban Kerbside
# 2                 Tally Ho AQMS   North Finchley  BN1: Urban Kerbside
# 3                 Tally Ho AQMS   North Finchley  BN1: Urban Kerbside
# 4                 Tally Ho AQMS   North Finchley  BN1: Urban Kerbside
#
#      End Date  End Time  PM10               Units   NO2 Units.1
# ...

# %%
connection_string = "postgres:postgres@localhost:5432/ETL_project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['seoul', 'uk']
